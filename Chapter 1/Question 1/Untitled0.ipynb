# %% [markdown]
# <a href="https://colab.research.google.com/github/nazaninbondarian/MachineLearning2024/blob/main/Chapter%201/Question%201/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Generate Dataset"""
import matplotlib.pyplot as plt
from sklearn.datasets import  make_classification
X, y = make_classification(n_samples=1000, n_features=3,
                           n_redundant=0, n_clusters_per_class=1,
                           class_sep=1, n_classes=4, random_state=76)

print(X.shape, y.shape)
# Out:
# (1000, 3) (1000,)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection="3d", elev=-150, azim=110)
ax.scatter(
    X[:, 0],
    X[:, 1],
    X[:, 2],
    c=y
)

ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("X3")
# Out:
# Text(0.5, 0, 'X3')

# %%
Xm, ym = make_classification(n_samples=1000, n_features=3,
                           n_redundant=0, n_clusters_per_class=1,
                           class_sep=0.1, n_classes=4, random_state=76)

print(Xm.shape, ym.shape)
fig = plt.figure()
ax = fig.add_subplot(projection="3d", elev=-150, azim=110)
ax.scatter(
    Xm[:, 0],
    Xm[:, 1],
    Xm[:, 2],
    c=ym
)

ax.set_xlabel("X1")
ax.set_ylabel("X2")
ax.set_zlabel("X3")
# Out:
# (1000, 3) (1000,)
# Text(0.5, 0, 'X3')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, SGDClassifier

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((800, 3), (800,), (200, 3), (200,))
