# %% [markdown]
# <a href="https://colab.research.google.com/github/nazaninbondarian/MachineLearning2024/blob/main/Chapter%201/Question%203/Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%cd ..
# Out:
# /content

# %%
import os

# Define the folder name
folder_name = "Data"

# Check if the folder already exists, and create it if not
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Commented out IPython magic to ensure Python compatibility.
# %cd Data
# Out:
# /content/Data

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown 18V-q5dHZXseCcj3QnF1BMwqjUtvhFU9u
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=18V-q5dHZXseCcj3QnF1BMwqjUtvhFU9u
# To: /content/Data/weatherHistory.csv
# 100% 16.3M/16.3M [00:00<00:00, 174MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('/content/Data/weatherHistory.csv')
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
#Rows and Columns
df.shape
# Out:
# (96453, 12)

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
print(df.isnull().sum())
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
# Remove missing values in the column `Precip Type`
data_df = df.dropna(subset=["Precip Type"])
print(data_df.isnull().sum())
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
# Get shape of dataframe
data_df.shape
# Out:
# (95936, 12)

# %%
# Get description of each column
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 95936 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            95936 non-null  object
#  1   Summary                   95936 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           95936 non-null  float64
#  4   Apparent Temperature (C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind Speed (km/h)         95936 non-null  float64
#  7   Wind Bearing (degrees)    95936 non-null  float64
#  8   Visibility (km)           95936 non-null  float64
#  9   Loud Cover                95936 non-null  float64
#  10  Pressure (millibars)      95936 non-null  float64
#  11  Daily Summary             95936 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 9.5+ MB

# %%
cat = list(data_df.select_dtypes('O'))
cat
# Out:
# ['Formatted Date', 'Summary', 'Precip Type', 'Daily Summary']

# %%
num = list(data_df.select_dtypes(np.number))
num
# Out:
# ['Temperature (C)',
#  'Apparent Temperature (C)',
#  'Humidity',
#  'Wind Speed (km/h)',
#  'Wind Bearing (degrees)',
#  'Visibility (km)',
#  'Loud Cover',
#  'Pressure (millibars)']

# %%
data_df[num].corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992637 -0.632148
# Apparent Temperature (C)         0.992637                  1.000000 -0.602390
# Humidity                        -0.632148                 -0.602390  1.000000
# Wind Speed (km/h)                0.008304                 -0.057387 -0.224569
# Wind Bearing (degrees)           0.029937                  0.028951  0.000814
# Visibility (km)                  0.393719                  0.382589 -0.370511
# Loud Cover                            NaN                       NaN       NaN
# Pressure (millibars)            -0.005253                 -0.000037  0.005375
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008304                0.029937
# Apparent Temperature (C)          -0.057387                0.028951
# ...

# %%
import seaborn as sns
sns.heatmap(data_df[num].corr(), annot=True, cmap="YlGnBu")
plt.title('Heat map for feature selection')
plt.show()

# %%
fig,ax = plt.subplots(4,2,figsize = (30,20))

for i , subplot in zip(num,ax.flatten()):
    sns.histplot(data_df[i],ax =subplot,kde = True)
    plt.title('data_df[i]')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
df1 = data_df.drop(cat[:],axis=1)
scaled_data_df = pd.DataFrame(StandardScaler().fit_transform(df1),columns=df1.columns)
fig,ax = plt.subplots(4,2,figsize = (30,20))

for i , subplot in zip(num,ax.flatten()):
    sns.histplot(scaled_data_df[i],ax =subplot,kde = True)
    plt.title('data_df[i]')

plt.tight_layout()
plt.show()

# %%
X = scaled_data_df[['Humidity']]
y1 = scaled_data_df[['Temperature (C)']]
y2 = scaled_data_df[['Apparent Temperature (C)']]
print(X.shape)
print(y1.shape)
print(y2.shape)
# Out:
# (95936, 1)
# (95936, 1)
# (95936, 1)

# %%
sns.pairplot( scaled_data_df, x_vars = ['Humidity'],
             y_vars = ['Temperature (C)','Apparent Temperature (C)'])

# %%
# Least Square regression
class LinearRegressionLS:
  def __init__(self):
    self.coefficients = None

  def fit(self, X, y):
    # Add a column of ones to account for the intercept term
    X = np.column_stack((np.ones(len(X)), X))

    # Compute the coefficients using the least squares method
    self.coefficients = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

  def predict(self, X):
    # Add a column of ones to account for the intercept term
    X = np.column_stack((np.ones(len(X)), X))

    # Predict the target variable
    return X.dot(self.coefficients)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Split the dataset into training and testing sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y1, test_size=0.2, random_state=76)
X_train1.shape, y_train1.shape, X_test1.shape, y_test1.shape
# Out:
# ((76748, 1), (76748, 1), (19188, 1), (19188, 1))

# %%
# Initialize and fit the linear regression model using least squares
model1a = LinearRegressionLS()
model1a.fit(X_train1, y_train1)
# Make predictions on the testing set
y_pred1a = model1a.predict(X_test1)

# %%
# Calculate Mean Squared Error
mse1a = mean_squared_error(y_test1, y_pred1a)
print("Mean Squared Error:", mse1a)
# Out:
# Mean Squared Error: 0.5969746762657372

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test1, y_pred1a, color='blue')
plt.plot([y_test1.min(), y_test1.max()], [y_test1.min(), y_test1.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.grid(True)
plt.show()

# %%
# Split the dataset into training and testing sets
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y2, test_size=0.2, random_state=76)
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape
# Out:
# ((76748, 1), (76748, 1), (19188, 1), (19188, 1))

# %%
# Initialize and fit the linear regression model using least squares
model2a = LinearRegressionLS()
model2a.fit(X_train2, y_train2)
# Make predictions on the testing set
y_pred2a = model2a.predict(X_test2)

# %%
# Calculate Mean Squared Error
mse2a = mean_squared_error(y_test2, y_pred2a)
print("Mean Squared Error:", mse2a)
# Out:
# Mean Squared Error: 0.6375466247376951

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test2, y_pred2a, color='blue')
plt.plot([y_test2.min(), y_test2.max()], [y_test2.min(), y_test2.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.grid(True)
plt.show()

# %%
X_n = scaled_data_df[['Apparent Temperature (C)']]
y_n = scaled_data_df[['Temperature (C)']]

print(X_n.shape)
print(y_n.shape)
# Out:
# (95936, 1)
# (95936, 1)

# %%
sns.pairplot( scaled_data_df, x_vars = ['Humidity','Apparent Temperature (C)'],
             y_vars = ['Temperature (C)'])

# %%
# Split the dataset into training and testing sets
X_train3, X_test3, y_train3, y_test3 = train_test_split(X_n, y_n, test_size=0.2, random_state=76)
X_train3.shape, y_train3.shape, X_test3.shape, y_test3.shape
# Out:
# ((76748, 1), (76748, 1), (19188, 1), (19188, 1))

# %%
# Initialize and fit the linear regression model using least squares
model3a = LinearRegressionLS()
model3a.fit(X_train3, y_train3)
# Make predictions on the testing set
y_pred3a = model3a.predict(X_test3)

# %%
# Calculate Mean Squared Error
mse3a = mean_squared_error(y_test3, y_pred3a)
print("Mean Squared Error:", mse3a)
# Out:
# Mean Squared Error: 0.014550000406755059

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test3, y_pred3a, color='blue')
plt.plot([y_test3.min(), y_test3.max()], [y_test3.min(), y_test3.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.grid(True)
plt.show()

# %%
# Recursive Least Squares (RLS)
class RecursiveLeastSquares:
  def __init__(self, n_features, forgetting_factor=0.995):
    self.n_features = n_features
    self.forgetting_factor = forgetting_factor
    self.theta = np.zeros((n_features, 1))  # Initialize model parameters
    self.P = np.eye(n_features)  # Initialize covariance matrix

  def fit(self, X, y):
    errors = []
    for i in range(len(X)):
      x_i = X[i].reshape(-1, 1)
      y_i = y[i]

      # Predict
      y_pred = np.dot(x_i.T, self.theta)

      # Update
      error = y_i - y_pred
      errors.append(error)
      K = np.dot(self.P, x_i) / (self.forgetting_factor + np.dot(np.dot(x_i.T, self.P), x_i))
      self.theta = self.theta + np.dot(K, error)
      self.P = (1 / self.forgetting_factor) * (self.P - np.dot(K, np.dot(x_i.T, self.P)))

    return errors

  def predict(self, X):
    return np.dot(X, self.theta)

# %%
# Initialize and fit the RLS model
rls1b = RecursiveLeastSquares(n_features=1)
errors1b=rls1b.fit(X_train1.values, y_train1.values)
# Make predictions
y_pred1b = rls1b.predict(X_test1.values)

# %%
# Calculate Mean Squared Error
mse1b = np.mean(np.array(errors1b)**2)
print("Mean Squared Error:", mse1b)
# Out:
# Mean Squared Error: 0.602827200423407

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test1, y_pred1b, color='blue')
plt.plot([y_test1.min(), y_test1.max()], [y_test1.min(), y_test1.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values (Boston Housing dataset)')
plt.grid(True)
plt.show()

# %%
# Initialize and fit the RLS model
rls2b = RecursiveLeastSquares(n_features=1)
errors2b=rls2b.fit(X_train2.values, y_train2.values)
# Make predictions
y_pred2b = rls2b.predict(X_test2.values)

# %%
# Calculate Mean Squared Error
mse2b = np.mean(np.array(errors2b)**2)
print("Mean Squared Error:", mse2b)
# Out:
# Mean Squared Error: 0.6385307267271296

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test2, y_pred2b, color='blue')
plt.plot([y_test2.min(), y_test2.max()], [y_test2.min(), y_test2.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values (Boston Housing dataset)')
plt.grid(True)
plt.show()

# %%
# Initialize and fit the RLS model
rls3b = RecursiveLeastSquares(n_features=1)
errors3b=rls3b.fit(X_train3.values, y_train3.values)
# Make predictions
y_pred3b = rls3b.predict(X_test3.values)

# %%
# Calculate Mean Squared Error
mse3b = np.mean(np.array(errors3b)**2)
print("Mean Squared Error:", mse3b)
# Out:
# Mean Squared Error: 0.014805461127825596

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test3, y_pred3b, color='blue')
plt.plot([y_test3.min(), y_test3.max()], [y_test3.min(), y_test3.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values (Boston Housing dataset)')
plt.grid(True)
plt.show()

# %%
# %matplotlib inline
import statsmodels.api as sm

# %%
mod1 = sm.RecursiveLS(X_train1, y_train1)
res1 = mod1.fit()

print(res1.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                            Statespace Model Results
# ...
# Dep. Variable:               Humidity   No. Observations:                76748
# Model:                    RecursiveLS   Log Likelihood              -89343.507
# Date:                Sat, 06 Apr 2024   R-squared:                       0.400
# Time:                        18:32:13   AIC                         178689.015
# Sample:                             0   BIC                         178698.263
#                               - 76748   HQIC                        178691.855
# Covariance Type:            nonrobust   Scale                            0.601
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
print(res1.recursive_coefficients.filtered[0])
res1.plot_recursive_coefficient(range(mod1.k_exog), alpha=None)
# Out:
# [-0.63627115 -0.63441604 -0.78415507 ... -0.63214787 -0.63214506
#  -0.63214683]

# %%
print(res1.cusum)
fig = res1.plot_cusum()
# Out:
# [-0.01774488  0.6431582  -0.42827584 ... -1.24400846 -1.80993565
#  -2.02245858]

# %%
res1.plot_cusum_squares()

# %%
mod2 = sm.RecursiveLS(X_train2, y_train2)
res2 = mod2.fit()

print(res2.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                            Statespace Model Results
# ...
# Dep. Variable:               Humidity   No. Observations:                76748
# Model:                    RecursiveLS   Log Likelihood              -91608.988
# Date:                Sat, 06 Apr 2024   R-squared:                       0.364
# Time:                        18:32:37   AIC                         183219.976
# Sample:                             0   BIC                         183229.224
#                               - 76748   HQIC                        183222.816
# Covariance Type:            nonrobust   Scale                            0.637
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
print(res2.recursive_coefficients.filtered[0])
res2.plot_recursive_coefficient(range(mod2.k_exog), alpha=None)
# Out:
# [-0.56780451 -0.56210413 -0.68961623 ... -0.60300025 -0.60299769
#  -0.60299968]

# %%
print(res2.cusum)
fig = res2.plot_cusum()
# Out:
# [-0.05201641  0.81279829 -0.36719282 ... 17.02596328 16.50778593
#  16.28012432]

# %%
res2.plot_cusum_squares()

# %%
mod3 = sm.RecursiveLS(X_train3, y_train3)
res3 = mod3.fit()

print(res3.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#                               Statespace Model Results
# ...
# Dep. Variable:     Apparent Temperature (C)   No. Observations:                76748
# Model:                          RecursiveLS   Log Likelihood               53067.213
# Date:                      Sat, 06 Apr 2024   R-squared:                       0.985
# Time:                              18:33:02   AIC                        -106132.426
# Sample:                                   0   BIC                        -106123.178
#                                     - 76748   HQIC                       -106129.585
# Covariance Type:                  nonrobust   Scale                            0.015
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
print(res3.recursive_coefficients.filtered[0])
res3.plot_recursive_coefficient(range(mod3.k_exog), alpha=None)
# Out:
# [1.12058136 1.12724107 1.05476179 ... 0.99202493 0.99202484 0.99202504]

# %%
print(res3.cusum)
fig = res3.plot_cusum()
# Out:
# [ -0.40740918   1.63851331   1.14066641 ... 196.06006105 196.17273264
#  196.32520047]

# %%
res3.plot_cusum_squares()

# %%
# Weight Least Square regression
class LinearRegressionWLS:
  def __init__(self):
    self.coefficients = None

  def fit(self, X, y):
    # Add a column of ones to account for the intercept term
    X = np.column_stack((np.ones(len(X)), X))

    # Weight
    error_variance = 1.2  # Modify this value based on your estimation
    Q = 1 / error_variance

    # Compute the coefficients using the least squares method
    self.coefficients = np.linalg.inv(X.T.dot(Q).dot(X)).dot(X.T).dot(y)

  def predict(self, X):
    # Add a column of ones to account for the intercept term
    X = np.column_stack((np.ones(len(X)), X))

    # Predict the target variable
    return X.dot(self.coefficients)

# %%
# Initialize and fit the linear regression model using least squares
wls1c = LinearRegressionWLS()
wls1c.fit(X_train1, y_train1)
# Make predictions on the testing set
y_pred1c = wls1c.predict(X_test1)

# %%
# Calculate Mean Squared Error
mse1c = mean_squared_error(y_test1, y_pred1c)
print("Mean Squared Error:", mse1c)
# Out:
# Mean Squared Error: 0.613759052252272

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test1, y_pred1c, color='blue')
plt.plot([y_test1.min(), y_test1.max()], [y_test1.min(), y_test1.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values (Boston Housing dataset)')
plt.grid(True)
plt.show()

# %%
# Initialize and fit the linear regression model using least squares
wls2c = LinearRegressionWLS()
wls2c.fit(X_train2, y_train2)
# Make predictions on the testing set
y_pred2c = wls2c.predict(X_test2)

# %%
# Calculate Mean Squared Error
mse2c = mean_squared_error(y_test2, y_pred2c)
print("Mean Squared Error:", mse2c)
# Out:
# Mean Squared Error: 0.652621156329484

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test2, y_pred2c, color='blue')
plt.plot([y_test2.min(), y_test2.max()], [y_test2.min(), y_test2.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values (Boston Housing dataset)')
plt.grid(True)
plt.show()

# %%
# Initialize and fit the linear regression model using least squares
wls3c = LinearRegressionWLS()
wls3c.fit(X_train3, y_train3)
# Make predictions on the testing set
y_pred3c = wls3c.predict(X_test3)

# %%
# Calculate Mean Squared Error
mse3c = mean_squared_error(y_test3, y_pred3c)
print("Mean Squared Error:", mse3c)
# Out:
# Mean Squared Error: 0.055089702256967854

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test3, y_pred3c, color='blue')
plt.plot([y_test3.min(), y_test3.max()], [y_test3.min(), y_test3.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values (Boston Housing dataset)')
plt.grid(True)
plt.show()

# %%
# Weighted Least Square
error_variance = 1.2  # Modify this value based on your estimation
weights1 = 1 / error_variance
X_with_intercept1 = sm.add_constant(X_train1)  # Add intercept term
model1 = sm.WLS(y_train1, X_with_intercept1, weights=weights1)
result1 = model1.fit()
# Print the model summary
print(result1.summary())
# Out:
#                             WLS Regression Results
# ...
# Dep. Variable:        Temperature (C)   R-squared:                       0.400
# Model:                            WLS   Adj. R-squared:                  0.400
# Method:                 Least Squares   F-statistic:                 5.117e+04
# Date:                Sat, 06 Apr 2024   Prob (F-statistic):               0.00
# Time:                        17:40:45   Log-Likelihood:                -89378.
# No. Observations:               76748   AIC:                         1.788e+05
# Df Residuals:                   76746   BIC:                         1.788e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.448e-06      0.003     -0.002      0.998      -0.005       0.005
# ...

# %%
# Weighted Least Square
error_variance = 1.2  # Modify this value based on your estimation
weights2 = 1 / error_variance
X_with_intercept2 = sm.add_constant(X_train2)  # Add intercept term
model2 = sm.WLS(y_train2, X_with_intercept2, weights=weights2)
result2 = model2.fit()
# Print the model summary
print(result2.summary())
# Out:
#                                WLS Regression Results
# ...
# Dep. Variable:     Apparent Temperature (C)   R-squared:                       0.364
# Model:                                  WLS   Adj. R-squared:                  0.364
# Method:                       Least Squares   F-statistic:                 4.384e+04
# Date:                      Sat, 06 Apr 2024   Prob (F-statistic):               0.00
# Time:                              17:40:39   Log-Likelihood:                -91596.
# No. Observations:                     76748   AIC:                         1.832e+05
# Df Residuals:                         76746   BIC:                         1.832e+05
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.003      0.104      0.917      -0.005       0.006
# ...

# %%
# Weighted Least Square
error_variance = 1.2  # Modify this value based on your estimation
weights3 = 1 / error_variance
X_with_intercept3 = sm.add_constant(X_train3)  # Add intercept term
model3 = sm.WLS(y_train3, X_with_intercept3, weights=weights3)
result3 = model3.fit()
# Print the model summary
print(result3.summary())
# Out:
#                             WLS Regression Results
# ...
# Dep. Variable:        Temperature (C)   R-squared:                       0.985
# Model:                            WLS   Adj. R-squared:                  0.985
# Method:                 Least Squares   F-statistic:                 5.154e+06
# Date:                Sat, 06 Apr 2024   Prob (F-statistic):               0.00
# Time:                        17:40:33   Log-Likelihood:                 53028.
# No. Observations:               76748   AIC:                        -1.061e+05
# Df Residuals:                   76746   BIC:                        -1.060e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.0003      0.000     -0.695      0.487      -0.001       0.001
# ...
