# %% [markdown]
# <a href="https://colab.research.google.com/github/nazaninbondarian/MachineLearning2024/blob/main/Chapter%201/Questio3/Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Define the folder name
folder_name = "Data"

# Check if the folder already exists, and create it if not
if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# Commented out IPython magic to ensure Python compatibility.
#%cd Data
#%cd ..
# Out:
# /content/Data

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown 18V-q5dHZXseCcj3QnF1BMwqjUtvhFU9u
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=18V-q5dHZXseCcj3QnF1BMwqjUtvhFU9u
# To: /content/Data/weatherHistory.csv
# 100% 16.3M/16.3M [00:00<00:00, 220MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv('/content/Data/weatherHistory.csv')
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
#Rows and Columns
df.shape
# Out:
# (96453, 12)

# %%
df.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
print(df.isnull().sum())
# Out:
# Formatted Date                0
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
# Remove missing values in the column `Precip Type`
data_df = df.dropna(subset=["Precip Type"])
print(data_df.isnull().sum())
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# dtype: int64

# %%
# Get shape of dataframe
data_df.shape
# Out:
# (95936, 12)

# %%
# Get description of each column
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 95936 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            95936 non-null  object
#  1   Summary                   95936 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           95936 non-null  float64
#  4   Apparent Temperature (C)  95936 non-null  float64
#  5   Humidity                  95936 non-null  float64
#  6   Wind Speed (km/h)         95936 non-null  float64
#  7   Wind Bearing (degrees)    95936 non-null  float64
#  8   Visibility (km)           95936 non-null  float64
#  9   Loud Cover                95936 non-null  float64
#  10  Pressure (millibars)      95936 non-null  float64
#  11  Daily Summary             95936 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 9.5+ MB

# %%
data_df.corr()
# Out:
# <ipython-input-203-b47fa4ad56a1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_df.corr()
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992637 -0.632148
# Apparent Temperature (C)         0.992637                  1.000000 -0.602390
# Humidity                        -0.632148                 -0.602390  1.000000
# Wind Speed (km/h)                0.008304                 -0.057387 -0.224569
# Wind Bearing (degrees)           0.029937                  0.028951  0.000814
# Visibility (km)                  0.393719                  0.382589 -0.370511
# Loud Cover                            NaN                       NaN       NaN
# Pressure (millibars)            -0.005253                 -0.000037  0.005375
#
# ...

# %%
import seaborn as sns
sns.heatmap(data_df.corr(), annot=True, cmap="YlGnBu")
plt.title('Heat map for feature selection')
plt.show()
# Out:
# <ipython-input-204-add4d9bbfc11>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_df.corr(), annot=True, cmap="YlGnBu")

# %%
cat = list(data_df.select_dtypes('O'))
cat
# Out:
# ['Formatted Date', 'Summary', 'Precip Type', 'Daily Summary']

# %%
num = list(data_df.select_dtypes(np.number))
num
# Out:
# ['Temperature (C)',
#  'Apparent Temperature (C)',
#  'Humidity',
#  'Wind Speed (km/h)',
#  'Wind Bearing (degrees)',
#  'Visibility (km)',
#  'Loud Cover',
#  'Pressure (millibars)']

# %%
fig,ax = plt.subplots(4,2,figsize = (30,20))

for i , subplot in zip(num,ax.flatten()):
    sns.histplot(data_df[i],ax =subplot,kde = True)
    plt.title('data_df[i]')

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
df1 = data_df.drop(cat[:],axis=1)
scaled_data_df = pd.DataFrame(StandardScaler().fit_transform(df1),columns=df1.columns)
fig,ax = plt.subplots(4,2,figsize = (30,20))

for i , subplot in zip(num,ax.flatten()):
    sns.histplot(scaled_data_df[i],ax =subplot,kde = True)
    plt.title('data_df[i]')

plt.tight_layout()
plt.show()

# %%
X = scaled_data_df[['Humidity']]
y1 = scaled_data_df[['Temperature (C)']]
y2 = scaled_data_df[['Apparent Temperature (C)']]
print(X.shape)
print(y1.shape)
print(y2.shape)
# Out:
# (95936, 1)
# (95936, 1)
# (95936, 1)

# %%
sns.pairplot( scaled_data_df, x_vars = ['Humidity'],
             y_vars = ['Temperature (C)','Apparent Temperature (C)'])

# %%
# Least Square regression
class LinearRegressionLS:
  def __init__(self):
    self.coefficients = None

  def fit(self, X, y):
    # Add a column of ones to account for the intercept term
    X = np.column_stack((np.ones(len(X)), X))

    # Compute the coefficients using the least squares method
    self.coefficients = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

  def predict(self, X):
    # Add a column of ones to account for the intercept term
    X = np.column_stack((np.ones(len(X)), X))

    # Predict the target variable
    return X.dot(self.coefficients)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Split the dataset into training and testing sets
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y1, test_size=0.2, random_state=76)
X_train1.shape, y_train1.shape, X_test1.shape, y_test1.shape
# Out:
# ((76748, 1), (76748, 1), (19188, 1), (19188, 1))

# %%
# Initialize and fit the linear regression model using least squares\n",
model1a = LinearRegressionLS()
model1a.fit(X_train1, y_train1)
# Make predictions on the testing set
y_pred1a = model1a.predict(X_test1)

# %%
# Calculate Mean Squared Error
mse1a = mean_squared_error(y_test1, y_pred1a)
print("Mean Squared Error:", mse1a)
# Out:
# Mean Squared Error: 0.5969746762657372

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test1, y_pred1a, color='blue')
plt.plot([y_test1.min(), y_test1.max()], [y_test1.min(), y_test1.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.grid(True)
plt.show()

# %%
# Split the dataset into training and testing sets
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y2, test_size=0.2, random_state=76)
X_train2.shape, y_train2.shape, X_test2.shape, y_test2.shape
# Out:
# ((76748, 1), (76748, 1), (19188, 1), (19188, 1))

# %%
# Initialize and fit the linear regression model using least squares\n",
model2a = LinearRegressionLS()
model2a.fit(X_train2, y_train2)
# Make predictions on the testing set
y_pred2a = model2a.predict(X_test2)

# %%
# Calculate Mean Squared Error
mse2a = mean_squared_error(y_test2, y_pred2a)
print("Mean Squared Error:", mse2a)
# Out:
# Mean Squared Error: 0.6375466247376951

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test2, y_pred2a, color='blue')
plt.plot([y_test2.min(), y_test2.max()], [y_test2.min(), y_test2.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.grid(True)
plt.show()

# %%
X_n = scaled_data_df[['Apparent Temperature (C)']]
y_n = scaled_data_df[['Temperature (C)']]

print(X_n.shape)
print(y_n.shape)
# Out:
# (95936, 1)
# (95936, 1)

# %%
sns.pairplot( scaled_data_df, x_vars = ['Humidity','Apparent Temperature (C)'],
             y_vars = ['Temperature (C)'])

# %%
# Split the dataset into training and testing sets
X_train3, X_test3, y_train3, y_test3 = train_test_split(X_n, y_n, test_size=0.2, random_state=76)
X_train3.shape, y_train3.shape, X_test3.shape, y_test3.shape
# Out:
# ((76748, 1), (76748, 1), (19188, 1), (19188, 1))

# %%
# Initialize and fit the linear regression model using least squares\n",
model3a = LinearRegressionLS()
model3a.fit(X_train3, y_train3)
# Make predictions on the testing set
y_pred3a = model3a.predict(X_test3)

# %%
# Calculate Mean Squared Error
mse3a = mean_squared_error(y_test3, y_pred3a)
print("Mean Squared Error:", mse3a)
# Out:
# Mean Squared Error: 0.014550000406755059

# %%
# Plot actual vs predicted values
plt.figure(figsize=(10, 6))
plt.scatter(y_test3, y_pred3a, color='blue')
plt.plot([y_test3.min(), y_test3.max()], [y_test3.min(), y_test3.max()], color='red', linestyle='--')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.grid(True)
plt.show()
